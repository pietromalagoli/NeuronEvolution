# %% [markdown]
# Testing some JAX functionalities to get the hang of it.

# %%
import jax 
import jax.numpy as jnp
import jax.debug as jdb

# %%
jax.devices()
# Out:
# [cuda(id=0)]

# %%
import jax.numpy as jnp
arr = jnp.arange(32.0).reshape(4, 8)
arr.devices()
# Out:
# {cuda(id=0)}

# %%
arr.sharding
jdb.visualize_array_sharding(arr)
# Out:
#
#
#
#
#
#                       GPU 0
